# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities
#
# https://openweathermap.org/current
#
# instructions on how to make an API call

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %%
#<------ Showing the random cities selected:
N=15
print(cities[slice(N)])
# Out:
# ['georgetown', 'mirto', 'adamstown', 'avarua', 'edinburgh of the seven seas', 'utrik', 'katsuura', 'spring creek', 'sinabang', 'huarmey', 'kenai', 'badger', 'terra santa', 'nova sintra', 'chibougamau']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#<------ https://api.openweathermap.org/data/2.5/weather?
        #lat={lat}&lon={lon}&appid={API key}

url = "https://api.openweathermap.org/data/2.5/weather?"
#<------mode="Response format. Possible values are xml and html. Automatic .json"
unit="imperial"
#<------lang="You can use this parameter to get the output in your language."
        #spanish=sp, es --- frenche=fr

query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

response = requests.get(query_url).json()

# %%
#<------Built-in API request by city name
#<------https://api.openweathermap.org/data/2.5/weather?
        #q={city name},{state code},{country code}
        #&appid={API key}

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units={unit}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = (requests.get(city_url)).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lat"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["temp_min"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                           "Lat": city_lat, 
                           "Lng": city_lng, 
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                       "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | mirto
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | utrik
# Processing Record 7 of Set 1 | katsuura
# Processing Record 8 of Set 1 | spring creek
# Processing Record 9 of Set 1 | sinabang
# Processing Record 10 of Set 1 | huarmey
# Processing Record 11 of Set 1 | kenai
# Processing Record 12 of Set 1 | badger
# Processing Record 13 of Set 1 | terra santa
# Processing Record 14 of Set 1 | nova sintra
# Processing Record 15 of Set 1 | chibougamau
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | arak
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | hawaiian paradise park
# Processing Record 20 of Set 1 | sao vicente
# Processing Record 21 of Set 1 | igdir
# Processing Record 22 of Set 1 | qaqortoq
# Processing Record 23 of Set 1 | aasiaat
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 26 of Set 1 | roma
# Processing Record 27 of Set 1 | tazovsky
# Processing Record 28 of Set 1 | al bawiti
# Processing Record 29 of Set 1 | malango
# Processing Record 30 of Set 1 | menongue
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | siddipet
# Processing Record 33 of Set 1 | kristiansund
# Processing Record 34 of Set 1 | beterou
# Processing Record 35 of Set 1 | san luis de la loma
# Processing Record 36 of Set 1 | inarajan village
# Processing Record 37 of Set 1 | college
# Processing Record 38 of Set 1 | whitehorse
# Processing Record 39 of Set 1 | port-aux-francais
# Processing Record 40 of Set 1 | zarghun shahr
# Processing Record 41 of Set 1 | margaret river
# Processing Record 42 of Set 1 | yichun
# Processing Record 43 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 44 of Set 1 | guane
# Processing Record 45 of Set 1 | shenkursk
# Processing Record 46 of Set 1 | hamilton
# Processing Record 47 of Set 1 | tongouson
# Processing Record 48 of Set 1 | kapuskasing
# Processing Record 49 of Set 1 | sola
# Processing Record 50 of Set 1 | talnakh
# Processing Record 0 of Set 2 | kingston
# Processing Record 1 of Set 2 | ta`u
# Processing Record 2 of Set 2 | shahrak
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | wenchang
# Processing Record 8 of Set 2 | shangri-la
# City not found. Skipping...
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | stephenville
# Processing Record 11 of Set 2 | vorgashor
# Processing Record 12 of Set 2 | karaton
# Processing Record 13 of Set 2 | elista
# Processing Record 14 of Set 2 | papatowai
# Processing Record 15 of Set 2 | northam
# Processing Record 16 of Set 2 | vadso
# Processing Record 17 of Set 2 | toamasina
# Processing Record 18 of Set 2 | anloga
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | nuku'alofa
# Processing Record 23 of Set 2 | howard springs
# Processing Record 24 of Set 2 | timbuktu
# Processing Record 25 of Set 2 | vokhtoga
# Processing Record 26 of Set 2 | orangeburg
# Processing Record 27 of Set 2 | klaksvik
# Processing Record 28 of Set 2 | rouissat
# Processing Record 29 of Set 2 | fale old settlement
# Processing Record 30 of Set 2 | empangeni
# Processing Record 31 of Set 2 | kurchatov
# Processing Record 32 of Set 2 | la passe
# Processing Record 33 of Set 2 | la'ie
# Processing Record 34 of Set 2 | balykshi
# Processing Record 35 of Set 2 | kirensk
# Processing Record 36 of Set 2 | kiunga
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | olonkinbyen
# Processing Record 39 of Set 2 | mglin
# Processing Record 40 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 2 | vilhena
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | winnemucca
# Processing Record 45 of Set 2 | churapcha
# Processing Record 46 of Set 2 | port mathurin
# Processing Record 47 of Set 2 | karratha
# Processing Record 48 of Set 2 | invercargill
# Processing Record 49 of Set 2 | kulunda
# Processing Record 0 of Set 3 | san julian
# Processing Record 1 of Set 3 | waingapu
# Processing Record 2 of Set 3 | puerto natales
# Processing Record 3 of Set 3 | fort-shevchenko
# Processing Record 4 of Set 3 | dunedin
# Processing Record 5 of Set 3 | santa terezinha
# Processing Record 6 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 7 of Set 3 | enewetak
# Processing Record 8 of Set 3 | phek
# Processing Record 9 of Set 3 | dwarka
# Processing Record 10 of Set 3 | vorkuta
# Processing Record 11 of Set 3 | bozoum
# Processing Record 12 of Set 3 | durant
# Processing Record 13 of Set 3 | wailua homesteads
# Processing Record 14 of Set 3 | west island
# Processing Record 15 of Set 3 | kapa'a
# Processing Record 16 of Set 3 | ancud
# Processing Record 17 of Set 3 | stanley
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | trelew
# Processing Record 20 of Set 3 | tiksi
# Processing Record 21 of Set 3 | broken hill
# Processing Record 22 of Set 3 | lompoc
# Processing Record 23 of Set 3 | ust-nera
# Processing Record 24 of Set 3 | amiens
# Processing Record 25 of Set 3 | port lincoln
# Processing Record 26 of Set 3 | markaz-e hukumat-e darweshan
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 29 of Set 3 | puerto aysen
# Processing Record 30 of Set 3 | papao
# Processing Record 31 of Set 3 | beledweyne
# Processing Record 32 of Set 3 | grytviken
# Processing Record 33 of Set 3 | queenstown
# Processing Record 34 of Set 3 | hlusk
# Processing Record 35 of Set 3 | anadyr
# Processing Record 36 of Set 3 | kununurra
# Processing Record 37 of Set 3 | paungde
# Processing Record 38 of Set 3 | egilsstadir
# Processing Record 39 of Set 3 | greymouth
# Processing Record 40 of Set 3 | klyuchi
# Processing Record 41 of Set 3 | fort bragg
# Processing Record 42 of Set 3 | el haouaria
# Processing Record 43 of Set 3 | dudinka
# Processing Record 44 of Set 3 | zakamensk
# Processing Record 45 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 46 of Set 3 | st. john's
# Processing Record 47 of Set 3 | pangody
# Processing Record 48 of Set 3 | puerto baquerizo moreno
# Processing Record 49 of Set 3 | pacific grove
# Processing Record 0 of Set 4 | ilulissat
# Processing Record 1 of Set 4 | port-vila
# Processing Record 2 of Set 4 | green river
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | kokopo
# Processing Record 5 of Set 4 | al jawf
# Processing Record 6 of Set 4 | soanierana ivongo
# Processing Record 7 of Set 4 | muli
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | nzega
# Processing Record 10 of Set 4 | susuman
# Processing Record 11 of Set 4 | yeppoon
# Processing Record 12 of Set 4 | atafu village
# Processing Record 13 of Set 4 | uthal
# Processing Record 14 of Set 4 | porto novo
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | cockburn town
# Processing Record 17 of Set 4 | kerikeri
# Processing Record 18 of Set 4 | saint-pierre
# Processing Record 19 of Set 4 | udachny
# Processing Record 20 of Set 4 | lihue
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | herning
# Processing Record 23 of Set 4 | tomatlan
# Processing Record 24 of Set 4 | mao
# Processing Record 25 of Set 4 | chonchi
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | chaoyang
# Processing Record 28 of Set 4 | midelt
# Processing Record 29 of Set 4 | nalut
# Processing Record 30 of Set 4 | ribeira grande
# Processing Record 31 of Set 4 | puerto ayora
# Processing Record 32 of Set 4 | floro
# Processing Record 33 of Set 4 | villa gesell
# Processing Record 34 of Set 4 | suntar
# Processing Record 35 of Set 4 | mikomeseng
# Processing Record 36 of Set 4 | tura
# Processing Record 37 of Set 4 | horta
# Processing Record 38 of Set 4 | takoradi
# Processing Record 39 of Set 4 | nova vicosa
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | barakani
# Processing Record 42 of Set 4 | port alfred
# Processing Record 43 of Set 4 | vel'sk
# Processing Record 44 of Set 4 | hammerfest
# Processing Record 45 of Set 4 | jimeta
# Processing Record 46 of Set 4 | hailey
# Processing Record 47 of Set 4 | ulsteinvik
# Processing Record 48 of Set 4 | manacapuru
# Processing Record 49 of Set 4 | veymandoo
# City not found. Skipping...
# Processing Record 0 of Set 5 | severo-yeniseyskiy
# Processing Record 1 of Set 5 | santo domingo de la calzada
# Processing Record 2 of Set 5 | banda aceh
# Processing Record 3 of Set 5 | lashio
# Processing Record 4 of Set 5 | bafra
# Processing Record 5 of Set 5 | rawson
# Processing Record 6 of Set 5 | dubbo
# Processing Record 7 of Set 5 | mukalla
# Processing Record 8 of Set 5 | antofagasta
# Processing Record 9 of Set 5 | ballina
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | nizwa
# Processing Record 12 of Set 5 | mbanza kongo
# Processing Record 13 of Set 5 | weno
# Processing Record 14 of Set 5 | acapulco de juarez
# Processing Record 15 of Set 5 | ramon castilla
# Processing Record 16 of Set 5 | urangan
# Processing Record 17 of Set 5 | isafjordur
# Processing Record 18 of Set 5 | remire-montjoly
# Processing Record 19 of Set 5 | barra de santo antonio
# Processing Record 20 of Set 5 | hirara
# Processing Record 21 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 23 of Set 5 | musay'id
# City not found. Skipping...
# Processing Record 24 of Set 5 | skelleftea
# Processing Record 25 of Set 5 | tagab
# Processing Record 26 of Set 5 | dakhla
# Processing Record 27 of Set 5 | sitka
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | nehe
# Processing Record 30 of Set 5 | saipan
# Processing Record 31 of Set 5 | dryden
# Processing Record 32 of Set 5 | kapiri mposhi
# Processing Record 33 of Set 5 | new norfolk
# Processing Record 34 of Set 5 | jieshi
# Processing Record 35 of Set 5 | whangarei
# Processing Record 36 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 37 of Set 5 | paramonga
# Processing Record 38 of Set 5 | kolonia
# Processing Record 39 of Set 5 | kailua-kona
# Processing Record 40 of Set 5 | san antonio de pale
# Processing Record 41 of Set 5 | koksan
# Processing Record 42 of Set 5 | bozhou
# Processing Record 43 of Set 5 | olinda
# Processing Record 44 of Set 5 | hadibu
# Processing Record 45 of Set 5 | kudahuvadhoo
# Processing Record 46 of Set 5 | yuzhno-kurilsk
# Processing Record 47 of Set 5 | fehrbellin
# Processing Record 48 of Set 5 | nadi
# Processing Record 49 of Set 5 | hobyo
# Processing Record 0 of Set 6 | aoulef
# Processing Record 1 of Set 6 | lethem
# Processing Record 2 of Set 6 | zharkent
# Processing Record 3 of Set 6 | olonets
# Processing Record 4 of Set 6 | kyshtovka
# Processing Record 5 of Set 6 | eket
# Processing Record 6 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 6 | itaocara
# Processing Record 8 of Set 6 | kota kinabalu
# Processing Record 9 of Set 6 | bend
# Processing Record 10 of Set 6 | columbia falls
# Processing Record 11 of Set 6 | khanty-mansiysk
# Processing Record 12 of Set 6 | mount gambier
# Processing Record 13 of Set 6 | carloforte
# Processing Record 14 of Set 6 | tromso
# Processing Record 15 of Set 6 | uturoa
# Processing Record 16 of Set 6 | salahonda
# Processing Record 17 of Set 6 | ciudad lazaro cardenas
# Processing Record 18 of Set 6 | yangshuo
# Processing Record 19 of Set 6 | fortuna
# Processing Record 20 of Set 6 | jayapura
# Processing Record 21 of Set 6 | saint-philippe
# Processing Record 22 of Set 6 | matriz de camaragibe
# Processing Record 23 of Set 6 | guanica
# Processing Record 24 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 6 | forster
# Processing Record 26 of Set 6 | prineville
# Processing Record 27 of Set 6 | princeville
# Processing Record 28 of Set 6 | kaohsiung
# Processing Record 29 of Set 6 | valdivia
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | carnarvon
# Processing Record 33 of Set 6 | corner brook
# Processing Record 34 of Set 6 | yakeshi
# Processing Record 35 of Set 6 | cidreira
# Processing Record 36 of Set 6 | nurota
# Processing Record 37 of Set 6 | rizal
# Processing Record 38 of Set 6 | bychawa
# Processing Record 39 of Set 6 | mont-laurier
# Processing Record 40 of Set 6 | reggane
# Processing Record 41 of Set 6 | timisoara
# Processing Record 42 of Set 6 | roseburg north
# Processing Record 43 of Set 6 | rio gallegos
# Processing Record 44 of Set 6 | primero de mayo
# Processing Record 45 of Set 6 | san rafael del yuma
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | chincha alta
# Processing Record 48 of Set 6 | sechelt
# Processing Record 49 of Set 6 | happy valley-goose bay
# Processing Record 0 of Set 7 | pudasjarvi
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | soroca
# Processing Record 3 of Set 7 | onega
# Processing Record 4 of Set 7 | sharhorod
# Processing Record 5 of Set 7 | tvoroyri
# Processing Record 6 of Set 7 | chiili
# City not found. Skipping...
# Processing Record 7 of Set 7 | lanivtsi
# Processing Record 8 of Set 7 | el granada
# Processing Record 9 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 10 of Set 7 | madera
# Processing Record 11 of Set 7 | bilgoraj
# Processing Record 12 of Set 7 | ilha de mocambique
# Processing Record 13 of Set 7 | fougamou
# Processing Record 14 of Set 7 | khandyga
# Processing Record 15 of Set 7 | bonthe
# Processing Record 16 of Set 7 | behshahr
# Processing Record 17 of Set 7 | mangrol
# Processing Record 18 of Set 7 | tindouf
# Processing Record 19 of Set 7 | medina de rioseco
# Processing Record 20 of Set 7 | molde
# Processing Record 21 of Set 7 | mermoz boabab
# Processing Record 22 of Set 7 | ebon
# Processing Record 23 of Set 7 | inhambane
# Processing Record 24 of Set 7 | selfoss
# Processing Record 25 of Set 7 | kodiak
# Processing Record 26 of Set 7 | madison
# Processing Record 27 of Set 7 | tamanrasset
# Processing Record 28 of Set 7 | tosontsengel
# Processing Record 29 of Set 7 | bechar
# Processing Record 30 of Set 7 | naze
# Processing Record 31 of Set 7 | aykhal
# Processing Record 32 of Set 7 | constantia
# Processing Record 33 of Set 7 | aginskoye
# Processing Record 34 of Set 7 | kantemirovka
# Processing Record 35 of Set 7 | idaho falls
# Processing Record 36 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 37 of Set 7 | faya-largeau
# Processing Record 38 of Set 7 | inongo
# Processing Record 39 of Set 7 | sechura
# Processing Record 40 of Set 7 | nar'yan-mar
# Processing Record 41 of Set 7 | inekar
# City not found. Skipping...
# Processing Record 42 of Set 7 | mili
# Processing Record 43 of Set 7 | batticaloa
# Processing Record 44 of Set 7 | manicore
# Processing Record 45 of Set 7 | port glaud
# City not found. Skipping...
# Processing Record 46 of Set 7 | santa marta
# Processing Record 47 of Set 7 | aljezur
# Processing Record 48 of Set 7 | sirte
# Processing Record 49 of Set 7 | saksaul'skiy
# City not found. Skipping...
# Processing Record 0 of Set 8 | tanout
# Processing Record 1 of Set 8 | los frentones
# Processing Record 2 of Set 8 | goondiwindi
# Processing Record 3 of Set 8 | haenam
# Processing Record 4 of Set 8 | saldanha
# Processing Record 5 of Set 8 | sar-e pul
# Processing Record 6 of Set 8 | kavieng
# Processing Record 7 of Set 8 | amursk
# Processing Record 8 of Set 8 | attapeu
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | vilyuchinsk
# Processing Record 11 of Set 8 | callao
# Processing Record 12 of Set 8 | sarykemer
# Processing Record 13 of Set 8 | oranjemund
# Processing Record 14 of Set 8 | kyzyl-mazhalyk
# Processing Record 15 of Set 8 | man
# Processing Record 16 of Set 8 | tazacorte
# Processing Record 17 of Set 8 | abagur
# Processing Record 18 of Set 8 | jolo
# Processing Record 19 of Set 8 | praia
# Processing Record 20 of Set 8 | lorengau
# Processing Record 21 of Set 8 | magnitka
# Processing Record 22 of Set 8 | tolanaro
# Processing Record 23 of Set 8 | lagos
# Processing Record 24 of Set 8 | gisborne
# Processing Record 25 of Set 8 | preobrazheniye
# Processing Record 26 of Set 8 | prado
# Processing Record 27 of Set 8 | ghat
# Processing Record 28 of Set 8 | garoua boulai
# Processing Record 29 of Set 8 | labuan bajo
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | veraval
# Processing Record 32 of Set 8 | portland
# Processing Record 33 of Set 8 | codrington
# Processing Record 34 of Set 8 | zhongshu
# Processing Record 35 of Set 8 | ulaangom
# Processing Record 36 of Set 8 | nuuk
# Processing Record 37 of Set 8 | tralee
# Processing Record 38 of Set 8 | kokpekty
# Processing Record 39 of Set 8 | tullamore
# Processing Record 40 of Set 8 | itoman
# Processing Record 41 of Set 8 | malvan
# Processing Record 42 of Set 8 | tsiombe
# Processing Record 43 of Set 8 | yaritagua
# Processing Record 44 of Set 8 | paita
# Processing Record 45 of Set 8 | iskateley
# Processing Record 46 of Set 8 | port saint john's
# Processing Record 47 of Set 8 | abadeh
# Processing Record 48 of Set 8 | zaozersk
# Processing Record 49 of Set 8 | lakshettipet
# Processing Record 0 of Set 9 | petrolia
# Processing Record 1 of Set 9 | basse-terre
# Processing Record 2 of Set 9 | polyarnyy
# Processing Record 3 of Set 9 | tan-tan
# Processing Record 4 of Set 9 | fort st. john
# Processing Record 5 of Set 9 | san luis
# Processing Record 6 of Set 9 | nemuro
# Processing Record 7 of Set 9 | hovd
# Processing Record 8 of Set 9 | retreat
# Processing Record 9 of Set 9 | ishtixon shahri
# City not found. Skipping...
# Processing Record 10 of Set 9 | colon
# Processing Record 11 of Set 9 | amga
# Processing Record 12 of Set 9 | beatrice
# Processing Record 13 of Set 9 | minas de marcona
# Processing Record 14 of Set 9 | wingham
# Processing Record 15 of Set 9 | page
# Processing Record 16 of Set 9 | belyy yar
# Processing Record 17 of Set 9 | rio grande
# Processing Record 18 of Set 9 | ola
# Processing Record 19 of Set 9 | sinaloa de leyva
# Processing Record 20 of Set 9 | isle of arran
# City not found. Skipping...
# Processing Record 21 of Set 9 | opuwo
# Processing Record 22 of Set 9 | pandan
# Processing Record 23 of Set 9 | xiantao
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | holualoa
# Processing Record 26 of Set 9 | whakatane
# Processing Record 27 of Set 9 | ambon
# Processing Record 28 of Set 9 | sakakah
# Processing Record 29 of Set 9 | lodwar
# Processing Record 30 of Set 9 | val-d'or
# Processing Record 31 of Set 9 | richfield
# Processing Record 32 of Set 9 | kalabo
# Processing Record 33 of Set 9 | galliano
# Processing Record 34 of Set 9 | carlsbad
# Processing Record 35 of Set 9 | margate
# Processing Record 36 of Set 9 | camiri
# Processing Record 37 of Set 9 | beyneu
# Processing Record 38 of Set 9 | maracai
# Processing Record 39 of Set 9 | san lawrenz
# Processing Record 40 of Set 9 | motygino
# Processing Record 41 of Set 9 | west end
# Processing Record 42 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 43 of Set 9 | saudarkrokur
# Processing Record 44 of Set 9 | veragua arriba
# Processing Record 45 of Set 9 | tshikapa
# Processing Record 46 of Set 9 | vila franca do campo
# Processing Record 47 of Set 9 | afaahiti
# Processing Record 48 of Set 9 | tofol
# Processing Record 49 of Set 9 | verkhneural'sk
# Processing Record 0 of Set 10 | aldinga beach
# Processing Record 1 of Set 10 | nkove
# Processing Record 2 of Set 10 | taro
# Processing Record 3 of Set 10 | kolokani
# Processing Record 4 of Set 10 | vastaboland
# City not found. Skipping...
# Processing Record 5 of Set 10 | padang
# Processing Record 6 of Set 10 | puerto leguizamo
# Processing Record 7 of Set 10 | dalandzadgad
# Processing Record 8 of Set 10 | east london
# Processing Record 9 of Set 10 | wynyard
# Processing Record 10 of Set 10 | aitape
# Processing Record 11 of Set 10 | bubaque
# Processing Record 12 of Set 10 | warmbad
# Processing Record 13 of Set 10 | pogar
# Processing Record 14 of Set 10 | casper
# Processing Record 15 of Set 10 | bontang
# Processing Record 16 of Set 10 | revda
# Processing Record 17 of Set 10 | taoudenni
# Processing Record 18 of Set 10 | dubois
# Processing Record 19 of Set 10 | el calafate
# Processing Record 20 of Set 10 | arraial do cabo
# Processing Record 21 of Set 10 | pak phanang
# Processing Record 22 of Set 10 | sarmiento
# Processing Record 23 of Set 10 | lesparre-medoc
# Processing Record 24 of Set 10 | irtyshsk
# Processing Record 25 of Set 10 | big spring
# Processing Record 26 of Set 10 | felipe carrillo puerto
# Processing Record 27 of Set 10 | manadhoo
# Processing Record 28 of Set 10 | rice lake
# Processing Record 29 of Set 10 | vegreville
# Processing Record 30 of Set 10 | catemaco
# Processing Record 31 of Set 10 | estacion coahuila
# Processing Record 32 of Set 10 | akhmet'a
# Processing Record 33 of Set 10 | tavricheskoye
# Processing Record 34 of Set 10 | bardai
# Processing Record 35 of Set 10 | labytnangi
# Processing Record 36 of Set 10 | broome
# Processing Record 37 of Set 10 | montrose
# Processing Record 38 of Set 10 | cartagena del chaira
# Processing Record 39 of Set 10 | cold lake
# Processing Record 40 of Set 10 | shache
# Processing Record 41 of Set 10 | tshabong
# Processing Record 42 of Set 10 | conneaut
# Processing Record 43 of Set 10 | sao joao da barra
# Processing Record 44 of Set 10 | nagqu
# Processing Record 45 of Set 10 | utete
# Processing Record 46 of Set 10 | luanco
# Processing Record 47 of Set 10 | gadzhiyevo
# Processing Record 48 of Set 10 | daru
# Processing Record 49 of Set 10 | praia da vitoria
# Processing Record 0 of Set 11 | al artawiyah
# Processing Record 1 of Set 11 | hidrolandia
# Processing Record 2 of Set 11 | howrah
# Processing Record 3 of Set 11 | balancan
# Processing Record 4 of Set 11 | bousso
# Processing Record 5 of Set 11 | gorgan
# Processing Record 6 of Set 11 | ha'il
# Processing Record 7 of Set 11 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 11 | brookings
# Processing Record 9 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 11 | newman
# Processing Record 11 of Set 11 | vilyuysk
# Processing Record 12 of Set 11 | guroymak
# Processing Record 13 of Set 11 | alaghsas
# Processing Record 14 of Set 11 | khorixas
# Processing Record 15 of Set 11 | kasane
# Processing Record 16 of Set 11 | izberbash
# Processing Record 17 of Set 11 | nizhnesortymskiy
# Processing Record 18 of Set 11 | mezgor'e
# City not found. Skipping...
# Processing Record 19 of Set 11 | zhijiang
# Processing Record 20 of Set 11 | isla mujeres
# Processing Record 21 of Set 11 | laibin
# Processing Record 22 of Set 11 | lamu
# Processing Record 23 of Set 11 | cabo san lucas
# Processing Record 24 of Set 11 | north bend
# Processing Record 25 of Set 11 | darende
# Processing Record 26 of Set 11 | el porvenir
# Processing Record 27 of Set 11 | zeya
# Processing Record 28 of Set 11 | zhaobaoshan
# Processing Record 29 of Set 11 | ordos
# City not found. Skipping...
# Processing Record 30 of Set 11 | flin flon
# Processing Record 31 of Set 11 | gaiman
# Processing Record 32 of Set 11 | sao gabriel da cachoeira
# Processing Record 33 of Set 11 | lepsy
# Processing Record 34 of Set 11 | iwanai
# Processing Record 35 of Set 11 | ad dabbah
# Processing Record 36 of Set 11 | valentin gomez farias
# Processing Record 37 of Set 11 | aktobe
# Processing Record 38 of Set 11 | grand baie
# Processing Record 39 of Set 11 | krasnovishersk
# Processing Record 40 of Set 11 | kushiro
# Processing Record 41 of Set 11 | ust'-charyshskaya pristan'
# Processing Record 42 of Set 11 | kingscliff
# Processing Record 43 of Set 11 | priob'ye
# Processing Record 44 of Set 11 | zelenoborskiy
# Processing Record 45 of Set 11 | huangnihe
# Processing Record 46 of Set 11 | sambava
# Processing Record 47 of Set 11 | linxia chengguanzhen
# Processing Record 48 of Set 11 | maputo
# Processing Record 49 of Set 11 | myanaung
# Processing Record 0 of Set 12 | tahe
# Processing Record 1 of Set 12 | oltinko'l
# Processing Record 2 of Set 12 | noumea
# Processing Record 3 of Set 12 | ivdel'
# Processing Record 4 of Set 12 | merizo village
# Processing Record 5 of Set 12 | cabedelo
# Processing Record 6 of Set 12 | selma
# Processing Record 7 of Set 12 | porto empedocle
# Processing Record 8 of Set 12 | ducheng
# Processing Record 9 of Set 12 | kourou
# Processing Record 10 of Set 12 | mogadishu
# Processing Record 11 of Set 12 | morondava
# Processing Record 12 of Set 12 | ephrata
# Processing Record 13 of Set 12 | ashmun
# Processing Record 14 of Set 12 | baikonur
# Processing Record 15 of Set 12 | antsiranana
# Processing Record 16 of Set 12 | bulung'ur shahri
# City not found. Skipping...
# Processing Record 17 of Set 12 | charters towers
# Processing Record 18 of Set 12 | la ronge
# Processing Record 19 of Set 12 | saurimo
# Processing Record 20 of Set 12 | feijo
# Processing Record 21 of Set 12 | willowmore
# Processing Record 22 of Set 12 | lithgow
# Processing Record 23 of Set 12 | pisco
# Processing Record 24 of Set 12 | anton
# Processing Record 25 of Set 12 | mil'kovo
# Processing Record 26 of Set 12 | namibe
# Processing Record 27 of Set 12 | kualakapuas
# Processing Record 28 of Set 12 | ciudad insurgentes
# Processing Record 29 of Set 12 | ilek
# Processing Record 30 of Set 12 | ouallam
# Processing Record 31 of Set 12 | eraan
# Processing Record 32 of Set 12 | sur
# Processing Record 33 of Set 12 | dzuunharaa
# Processing Record 34 of Set 12 | tual
# Processing Record 35 of Set 12 | razole
# Processing Record 36 of Set 12 | greenville
# Processing Record 37 of Set 12 | piotrkow trybunalski
# Processing Record 38 of Set 12 | corn island
# Processing Record 39 of Set 12 | camana
# Processing Record 40 of Set 12 | mountain home
# Processing Record 41 of Set 12 | as sulayyil
# Processing Record 42 of Set 12 | plastun
# Processing Record 43 of Set 12 | mejit
# Processing Record 44 of Set 12 | boende
# Processing Record 45 of Set 12 | kone
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0                   georgetown   5.4112   5.4112     82.33     77.95
# 1                        mirto  38.0847  38.0847     84.31     83.26
# 2                    adamstown -25.0660 -25.0660     68.77     68.77
# 3                       avarua -21.2078 -21.2078     80.65     80.65
# 4  edinburgh of the seven seas -37.0676 -37.0676     56.19     56.19
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        5.01      MY  1690153429
# 1           1        7.52      IT  1690153460
# 2          22       17.11      PN  1690153461
# 3          75       12.66      CK  1690153461
# 4          58       24.23      SH  1690153282

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                         georgetown   5.4112   5.4112     82.33     77.95
# 1                              mirto  38.0847  38.0847     84.31     83.26
# 2                          adamstown -25.0660 -25.0660     68.77     68.77
# 3                             avarua -21.2078 -21.2078     80.65     80.65
# 4        edinburgh of the seven seas -37.0676 -37.0676     56.19     56.19
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                20        5.01      MY  1690153429
# 1                 1        7.52      IT  1690153460
# 2                22       17.11      PN  1690153461
# 3                75       12.66      CK  1690153461
# 4                58       24.23      SH  1690153282

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],
            s=6,color="b", marker="o")


# Incorporate the other graph properties

plt.xlabel('City Latitude',fontsize =10)
plt.ylabel('City Max Temperature ($^\circ$F)',fontsize =10)
plt.title('Latitude vs. Temperature')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],
            s=50,color="b", marker="*",edgecolors='b',alpha=.5)

# Incorporate the other graph properties
plt.xlabel('City Latitude',fontsize =10)
plt.ylabel('City Humidity',fontsize =10)
plt.title('Latitude vs. Humidity')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],
                s=10,color="purple", marker="*",edgecolors='b',alpha=1)

# Incorporate the other graph properties
plt.xlabel("City Latitude",fontsize=10)
plt.ylabel("City Cloudiness",fontsize=10)
plt.title("Latitude Vs. Cloudiness")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],
            s=20,color="pink", marker="p",edgecolors='b',alpha=.75)

# Incorporate the other graph properties
plt.xlabel("City Latitude",fontsize=10)
plt.ylabel("City Windspeed (mph)",fontsize=10)
plt.title("Latitude Vs. Windspeed")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.75)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regress(x,y, eqn_coordinates):
    r=st.pearsonr(x,y)
    print(f"The r-value is:{round(r[0],4)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y = {round(slope, 2)} x + {round(intercept, 2)}"
    plt.plot(x, regress_values, "r-")
    plt.annotate(line_eq, eqn_coordinates, fontsize=15, color="red")
    plt.scatter(x, y)
    plt.xlabel(f"{x.name}")
    plt.ylabel(f"{y.name}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"]>= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          georgetown   5.4112   5.4112     82.33     77.95          20
# 1               mirto  38.0847  38.0847     84.31     83.26           1
# 5               utrik  11.2278  11.2278     83.17     83.17          69
# 6            katsuura  35.1333  35.1333     79.03     79.03          43
# 7        spring creek  40.7266  40.7266     94.82     91.29          95
#
#          Wind Speed Country        Date
# City_ID
# 0              5.01      MY  1690153429
# 1              7.52      IT  1690153460
# 5             18.81      MH  1690153462
# 6              2.48      JP  1690153462
# 7             13.47      US  1690153463

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 2                          adamstown -25.0660 -25.0660     68.77     68.77
# 3                             avarua -21.2078 -21.2078     80.65     80.65
# 4        edinburgh of the seven seas -37.0676 -37.0676     56.19     56.19
# 9                            huarmey -10.0681 -10.0681     69.82     69.82
# 12                       terra santa  -2.1042  -2.1042     83.16     83.16
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                22       17.11      PN  1690153461
# 3                75       12.66      CK  1690153461
# 4                58       24.23      SH  1690153282
# 9                 0        9.80      PE  1690153464
# 12               30        3.87      BR  1690153465

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"), northern_hemi_df["Max Temp"],(0,50))
# Out:
# The r-value is:-0.599

# %%
# Linear regression on Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"), southern_hemi_df["Max Temp"],(-25,30))
# Out:
# The r-value is:0.8518

# %% [markdown]
# **Discussion about the linear relationship:**
#
# **Northern Hemisphere:**
#
# In the Northern Hemisphere, the statement indicates that there is a relatively strong negative correlation between temperature and latitude with a correlation coefficient of -0.599. A negative correlation means that as you move closer to the North Pole (increasing latitude), the temperature tends to decrease. This is a common observation, as regions closer to the poles generally experience colder temperatures.
#
#
# **Southern Hemisphere:**
#
# The statement suggests that there is a fairly strong positive correlation between temperature and latitude in the Southern Hemisphere. The correlation coefficient is given as 0.8518. A positive correlation indicates that as you move closer to the equator (increasing latitude from the south pole), the temperature tends to increase. This also aligns with the general understanding that areas closer to the equator experience warmer temperatures.
#
#
# These statements highlight the general temperature patterns as you move towards different latitudes in both hemispheres. The negative correlation in the Northern Hemisphere and positive correlation in the Southern Hemisphere are well-established climatic trends.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"),northern_hemi_df["Humidity"],(0,50))
# Out:
# The r-value is:-0.6252

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"),southern_hemi_df["Humidity"],(-25,30))
# Out:
# The r-value is:0.8598

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The relationship between humidity and latitude exhibits distinct patterns in both hemispheres. In the Northern Hemisphere, there is a relatively strong positive correlation between humidity and latitude, with a correlation coefficient of -0.6252. This suggests that as one moves further north from the equator, humidity tends to increase.
#
# On the other hand, in the Southern Hemisphere, there is also a relatively strong positive correlation between humidity and latitude, but with a correlation coefficient of 0.8598. This indicates that as one moves closer to the South Pole, humidity tends to increase. These findings underscore the different moisture trends associated with varying latitudinal positions in both hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"),northern_hemi_df["Cloudiness"],(100,100))
# Out:
# The r-value is:-0.0517

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"),southern_hemi_df["Cloudiness"],(50,50))
# Out:
# The r-value is:-0.0642

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The association between cloudiness and latitude demonstrates different strengths in the Northern and Southern Hemispheres. In the Northern Hemisphere, there exists a weak negative correlation with a coefficient of -0.0517. This suggests that cloudiness tends to slightly decrease as one moves north from the equator. The data reflects an immaterial change which can be concluded that there is no strong relationship between latitude and cloudiness in the north.
#
# The same can be said about the Southern Hemisphere, there is a relatively weak negative correlation with a coefficient of -0.0642. This indicates that cloudiness is more likely to increase as one moves closer to the South Pole. These contrasting results highlight the varying cloud patterns relative to latitude in each hemisphere.The data reflects an immaterial change which can be concluded that there is no strong relationship between latitude and cloudiness in the south.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemi_df["Lat"].rename("Latitude"),northern_hemi_df["Wind Speed"],(45,25))
# Out:
# The r-value is:-0.2286

# %%
# Southern Hemisphere
linear_regress(southern_hemi_df["Lat"].rename("Latitude"),southern_hemi_df["Wind Speed"],(-40,33))
# Out:
# The r-value is:-0.025

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The association between wind speeds and latitude demonstrates different strengths in the Northern and Southern Hemispheres. In the Northern Hemisphere, there exists a semi-weak negative correlation with a coefficient of -0.2286. This suggests that wind speeds tends to slightly decrease as one moves north from the equator.
#
# The Southern Hemisphere, there is a weak negative correlation with a coefficient of -0.0642. This indicates that wind speeds is more likely to increase as one moves closer to the South Pole. These contrasting results highlight the varying wind speed patterns relative to latitude in each hemisphere.The data reflects an immaterial change which can be concluded that there is no strong relationship between latitude and cloudiness in the south.
